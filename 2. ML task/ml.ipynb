# %%
from google.colab import drive
drive.mount('/content/drive')

path = 'data.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: category_encoders==2.8.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: joblib==1.5.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.5.2)
# Requirement already satisfied: matplotlib==3.10.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: optuna==4.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.5.0)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: shap==0.48.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.48.0)
# ERROR: Ignored the following yanked versions: 0.0.post2
# ERROR: Could not find a version that satisfies the requirement sklearn==1.6.1 (from versions: 0.0, 0.0.post1, 0.0.post4, 0.0.post5, 0.0.post7, 0.0.post9, 0.0.post10, 0.0.post11, 0.0.post12)
# ERROR: No matching distribution found for sklearn==1.6.1

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(path).set_index('ID')

# %%
data.head()
# Out:
#    Application creation month  NUMBER CREDITS IN KBI 3  \
# ID
# 1                      autumn                        0
# 2                      summer                        1
# 3                      autumn                        0
# 4                      autumn                        1
# 5                      spring                        1
#
#     NUMBER CREDITS IN KBI 6  ADMINISTRATIVE VIOLATION  CRIMINAL VIOLATION  \
# ID
# 1                         0                         0                   0
# 2                         2                         1                   2
# 3                         0                         0                   0
# 4                         1                         0                   0
# 5                         2                         2                   0
#
#     NUMBER CREDITS IN KBI  NUMBER REQUESTS IN KBI  NUMBER REQUESTS IN KBI ALL  \
# ID
# 1                       1                       1                           3
# 2                       1                       1                           4
# 3                       0                       0                           1
# 4                       3                       0                           2
# 5                       3                       0                          10
#
#     CLOSED CREDITS IN KBI  CLOSED CREDITS IN KBI YEAR  ...  REAL ESTATE  \
# ID                                                     ...
# 1                       2                           1  ...          yes
# 2                       3                           1  ...           no
# 3                       2                           2  ...          yes
# 4                       0                           0  ...          yes
# 5                      10                           4  ...          yes
#
#    VEHICLE  PERSONNEL PHONE  ACCOUNTING PHONE  Age  Length work  \
# ID
# 1      yes               no                no   34          8.0
# 2       no               no                no   46          5.0
# 3      yes               no                no   47          0.5
# 4      yes               no                no   36         10.0
# 5      yes               no                no   44         11.0
#
#    Matching address of registration and residence  Loans total  Credit load  \
# ID
# 1                                              no            3         0.21
# 2                                             yes            4         0.16
# 3                                             yes            2         0.05
# 4                                             yes            3         0.54
# 5                                             yes           13         0.34
#
#     Marker
# ID
# 1     good
# 2     good
# 3     good
# 4     good
# 5     good
#
# [5 rows x 55 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2565 entries, 1 to 2,565
# Data columns (total 55 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Application creation month                      2565 non-null   object
#  1   NUMBER CREDITS IN KBI 3                         2565 non-null   int64
#  2   NUMBER CREDITS IN KBI 6                         2565 non-null   int64
#  3   ADMINISTRATIVE VIOLATION                        2565 non-null   int64
#  4   CRIMINAL VIOLATION                              2565 non-null   int64
#  5   NUMBER CREDITS IN KBI                           2565 non-null   int64
#  6   NUMBER REQUESTS IN KBI                          2565 non-null   int64
#  7   NUMBER REQUESTS IN KBI ALL                      2565 non-null   int64
#  8   CLOSED CREDITS IN KBI                           2565 non-null   int64
#  9   CLOSED CREDITS IN KBI YEAR                      2565 non-null   int64
#  10  OVERDUES IN KBI                                 2565 non-null   int64
#  11  DURATION LAST OVERDUE                           2565 non-null   object
#  12  COUNTGUARANTEE                                  2565 non-null   int64
#  13  COUNTCLOSEGUARANTEE                             2565 non-null   int64
#  14  COUNTOPENGUARANTEE                              2565 non-null   int64
#  15  DURATIONGREATESTDELAYLASTYEAR                   2564 non-null   float64
#  16  DURATIONGREATESTDELAYLASTALL                    2565 non-null   object
#  17  LATECOUNTSUMM 1 7                               2565 non-null   int64
#  18  LATECOUNTSUMM 8 30                              2565 non-null   int64
#  19  LATECOUNTSUMM 31 90                             2565 non-null   int64
#  20  LATECOUNTSUMM 91 180                            2565 non-null   int64
#  21  LATECOUNTSUMM 181                               2565 non-null   int64
#  22  LATECOUNTPRC 1 7                                2565 non-null   int64
#  23  LATECOUNTPRC 8 30                               2565 non-null   int64
#  24  LATECOUNTPRC 31 90                              2565 non-null   int64
#  25  LATECOUNTPRC 91 180                             2565 non-null   int64
#  26  LATECOUNTPRC 181                                2565 non-null   int64
#  27  LATECOUNTPAY 1 7                                2565 non-null   int64
#  28  LATECOUNTPAY 8 30                               2565 non-null   int64
#  29  LATECOUNTPAY 31 90                              2565 non-null   int64
#  30  LATECOUNTPAY 91 180                             2565 non-null   int64
#  31  LATECOUNTPAY 181                                2565 non-null   int64
#  32  SEX                                             2565 non-null   object
#  33  BIRTH CNTR                                      2565 non-null   object
#  34  MARITAL STATUS                                  2565 non-null   object
#  35  CHILDREN                                        2565 non-null   int64
#  36  MINORS                                          2565 non-null   int64
#  37  HOMEPHONE                                       2565 non-null   object
#  38  WORKPHONE                                       2565 non-null   object
#  39  MOBILE 1                                        2565 non-null   object
#  40  REG TOWNTYPE                                    2565 non-null   object
#  41  HOME TOWNTYPE                                   2565 non-null   object
#  42  EMPLOYMENT                                      2565 non-null   object
#  43  EDUCATION                                       2565 non-null   object
#  44  PROFESSION                                      2565 non-null   object
#  45  REAL ESTATE                                     2565 non-null   object
#  46  VEHICLE                                         2565 non-null   object
#  47  PERSONNEL PHONE                                 2565 non-null   object
#  48  ACCOUNTING PHONE                                2565 non-null   object
#  49  Age                                             2565 non-null   int64
#  50  Length work                                     2565 non-null   float64
#  51  Matching address of registration and residence  2565 non-null   object
#  52  Loans total                                     2565 non-null   int64
#  53  Credit load                                     2565 non-null   float64
#  54  Marker                                          2565 non-null   object
# dtypes: float64(3), int64(32), object(20)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        NUMBER CREDITS IN KBI 3  NUMBER CREDITS IN KBI 6  \
# count              2565.000000              2565.000000
# mean                  0.215984                 0.593372
# std                   0.555902                 1.067695
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 1.000000
# max                   7.000000                17.000000
#
#        ADMINISTRATIVE VIOLATION  CRIMINAL VIOLATION  NUMBER CREDITS IN KBI  \
# count               2565.000000         2565.000000            2565.000000
# mean                   0.947368            0.147368               1.517739
# std                    1.958212            0.602353               1.431543
# min                    0.000000            0.000000               0.000000
# 25%                    0.000000            0.000000               0.000000
# 50%                    0.000000            0.000000               1.000000
# 75%                    1.000000            0.000000               2.000000
# max                   26.000000            6.000000              12.000000
#
#        NUMBER REQUESTS IN KBI  NUMBER REQUESTS IN KBI ALL  \
# count             2565.000000                 2565.000000
# mean                 0.642885                    5.689669
# std                  0.852381                    5.342810
# min                  0.000000                    0.000000
# 25%                  0.000000                    2.000000
# 50%                  0.000000                    4.000000
# 75%                  1.000000                    8.000000
# max                  9.000000                   61.000000
#
#        CLOSED CREDITS IN KBI  CLOSED CREDITS IN KBI YEAR  OVERDUES IN KBI  \
# count            2565.000000                 2565.000000      2565.000000
# mean                3.194542                    0.698246         0.816374
# std                 3.190880                    1.126625         2.479755
# min                 0.000000                    0.000000         0.000000
# 25%                 1.000000                    0.000000         0.000000
# 50%                 2.000000                    0.000000         0.000000
# 75%                 5.000000                    1.000000         0.000000
# max                37.000000                   16.000000        28.000000
#
#        ...  LATECOUNTPAY 8 30  LATECOUNTPAY 31 90  LATECOUNTPAY 91 180  \
# count  ...        2565.000000         2565.000000          2565.000000
# mean   ...           0.497856            0.106433             0.016374
# std    ...           2.083779            0.595728             0.152094
# min    ...           0.000000            0.000000             0.000000
# 25%    ...           0.000000            0.000000             0.000000
# 50%    ...           0.000000            0.000000             0.000000
# 75%    ...           0.000000            0.000000             0.000000
# max    ...          40.000000           12.000000             3.000000
#
#        LATECOUNTPAY 181     CHILDREN       MINORS          Age  Length work  \
# count       2565.000000  2565.000000  2565.000000  2565.000000  2565.000000
# mean           0.017934     1.224172     0.763743    38.118129     6.737661
# std            0.161862     0.929685     0.867337     9.880195     6.815279
# min            0.000000     0.000000     0.000000    21.000000     0.300000
# 25%            0.000000     1.000000     0.000000    30.000000     2.000000
# 50%            0.000000     1.000000     1.000000    37.000000     4.300000
# 75%            0.000000     2.000000     1.000000    45.000000     9.500000
# max            4.000000     7.000000     5.000000    64.000000    43.000000
#
#        Loans total  Credit load
# count  2565.000000  2565.000000
# mean      4.712281     0.194932
# std       3.993836     0.155481
# min       0.000000     0.000000
# 25%       2.000000     0.060000
# 50%       4.000000     0.160000
# 75%       7.000000     0.280000
# max      41.000000     0.970000
#
# [8 rows x 35 columns]

# %% [markdown]
# **EDA**

# %% [markdown]
# Предварительная обработка данных, выделение категориальных и интервальных переменных, обработка пропусков

# %%
data.columns
# Out:
# Index(['Application creation month', 'NUMBER CREDITS IN KBI 3',
#        'NUMBER CREDITS IN KBI 6', 'ADMINISTRATIVE VIOLATION',
#        'CRIMINAL VIOLATION', 'NUMBER CREDITS IN KBI', 'NUMBER REQUESTS IN KBI',
#        'NUMBER REQUESTS IN KBI ALL', 'CLOSED CREDITS IN KBI',
#        'CLOSED CREDITS IN KBI YEAR', 'OVERDUES IN KBI',
#        'DURATION LAST OVERDUE', 'COUNTGUARANTEE', 'COUNTCLOSEGUARANTEE',
#        'COUNTOPENGUARANTEE', 'DURATIONGREATESTDELAYLASTYEAR',
#        'DURATIONGREATESTDELAYLASTALL', 'LATECOUNTSUMM 1 7',
#        'LATECOUNTSUMM 8 30', 'LATECOUNTSUMM 31 90', 'LATECOUNTSUMM 91 180',
#        'LATECOUNTSUMM 181', 'LATECOUNTPRC 1 7', 'LATECOUNTPRC 8 30',
#        'LATECOUNTPRC 31 90', 'LATECOUNTPRC 91 180', 'LATECOUNTPRC 181',
#        'LATECOUNTPAY 1 7', 'LATECOUNTPAY 8 30', 'LATECOUNTPAY 31 90',
#        'LATECOUNTPAY 91 180', 'LATECOUNTPAY 181', 'SEX', 'BIRTH CNTR',
#        'MARITAL STATUS', 'CHILDREN', 'MINORS', 'HOMEPHONE', 'WORKPHONE',
#        'MOBILE 1', 'REG TOWNTYPE', 'HOME TOWNTYPE', 'EMPLOYMENT', 'EDUCATION',
#        'PROFESSION', 'REAL ESTATE', 'VEHICLE', 'PERSONNEL PHONE',
#        'ACCOUNTING PHONE', 'Age', 'Length work',
#        'Matching address of registration and residence', 'Loans total',
#        'Credit load', 'Marker'],
#       dtype='object')

# %%
data['Marker'] = data['Marker'].replace({'good': 1, 'bad': 0})
data.head()
# Out:
#    Application creation month  NUMBER CREDITS IN KBI 3  \
# ID
# 1                      autumn                        0
# 2                      summer                        1
# 3                      autumn                        0
# 4                      autumn                        1
# 5                      spring                        1
#
#     NUMBER CREDITS IN KBI 6  ADMINISTRATIVE VIOLATION  CRIMINAL VIOLATION  \
# ID
# 1                         0                         0                   0
# 2                         2                         1                   2
# 3                         0                         0                   0
# 4                         1                         0                   0
# 5                         2                         2                   0
#
#     NUMBER CREDITS IN KBI  NUMBER REQUESTS IN KBI  NUMBER REQUESTS IN KBI ALL  \
# ID
# 1                       1                       1                           3
# 2                       1                       1                           4
# 3                       0                       0                           1
# 4                       3                       0                           2
# 5                       3                       0                          10
#
#     CLOSED CREDITS IN KBI  CLOSED CREDITS IN KBI YEAR  ...  REAL ESTATE  \
# ID                                                     ...
# 1                       2                           1  ...          yes
# 2                       3                           1  ...           no
# 3                       2                           2  ...          yes
# 4                       0                           0  ...          yes
# 5                      10                           4  ...          yes
#
#    VEHICLE  PERSONNEL PHONE  ACCOUNTING PHONE  Age  Length work  \
# ID
# 1      yes               no                no   34          8.0
# 2       no               no                no   46          5.0
# 3      yes               no                no   47          0.5
# 4      yes               no                no   36         10.0
# 5      yes               no                no   44         11.0
#
#    Matching address of registration and residence  Loans total  Credit load  \
# ID
# 1                                              no            3         0.21
# 2                                             yes            4         0.16
# 3                                             yes            2         0.05
# 4                                             yes            3         0.54
# 5                                             yes           13         0.34
#
#     Marker
# ID
# 1        1
# 2        1
# 3        1
# 4        1
# 5        1
#
# [5 rows x 55 columns]

# %%
# только в первой строчке были наны
data = data.dropna()

# %%
features =['Application creation month', 'NUMBER CREDITS IN KBI 3',
       'NUMBER CREDITS IN KBI 6', 'ADMINISTRATIVE VIOLATION',
       'CRIMINAL VIOLATION', 'NUMBER CREDITS IN KBI', 'NUMBER REQUESTS IN KBI',
       'NUMBER REQUESTS IN KBI ALL', 'CLOSED CREDITS IN KBI',
       'CLOSED CREDITS IN KBI YEAR', 'OVERDUES IN KBI',
       'DURATION LAST OVERDUE', 'COUNTGUARANTEE', 'COUNTCLOSEGUARANTEE',
       'COUNTOPENGUARANTEE', 'DURATIONGREATESTDELAYLASTYEAR',
       'DURATIONGREATESTDELAYLASTALL', 'LATECOUNTSUMM 1 7',
       'LATECOUNTSUMM 8 30', 'LATECOUNTSUMM 31 90', 'LATECOUNTSUMM 91 180',
       'LATECOUNTSUMM 181', 'LATECOUNTPRC 1 7', 'LATECOUNTPRC 8 30',
       'LATECOUNTPRC 31 90', 'LATECOUNTPRC 91 180', 'LATECOUNTPRC 181',
       'LATECOUNTPAY 1 7', 'LATECOUNTPAY 8 30', 'LATECOUNTPAY 31 90',
       'LATECOUNTPAY 91 180', 'LATECOUNTPAY 181', 'SEX', 'BIRTH CNTR',
       'MARITAL STATUS', 'CHILDREN', 'MINORS', 'HOMEPHONE', 'WORKPHONE',
       'MOBILE 1', 'REG TOWNTYPE', 'HOME TOWNTYPE', 'EMPLOYMENT', 'EDUCATION',
       'PROFESSION', 'REAL ESTATE', 'VEHICLE', 'PERSONNEL PHONE',
       'ACCOUNTING PHONE', 'Age', 'Length work',
       'Matching address of registration and residence', 'Loans total',
       'Credit load']

# %%
# категориальные признаки из датафрейма
categorical = []
for c in data.columns:
  if data[c].dtype == 'object':
    categorical.append(c)
categorical
# Out:
# ['Application creation month',
#  'DURATION LAST OVERDUE',
#  'DURATIONGREATESTDELAYLASTALL',
#  'SEX',
#  'BIRTH CNTR',
#  'MARITAL STATUS',
#  'HOMEPHONE',
#  'WORKPHONE',
#  'MOBILE 1',
#  'REG TOWNTYPE',
#  'HOME TOWNTYPE',
#  'EMPLOYMENT',
#  'EDUCATION',
#  'PROFESSION',
#  'REAL ESTATE',
#  'VEHICLE',
#  'PERSONNEL PHONE',
#  'ACCOUNTING PHONE',
#  'Matching address of registration and residence']

# %%
# числовые признаки
numerical = list(set(features) - set(categorical))
numerical
# Out:
# ['LATECOUNTSUMM 8 30',
#  'Length work',
#  'NUMBER CREDITS IN KBI 6',
#  'OVERDUES IN KBI',
#  'LATECOUNTSUMM 31 90',
#  'COUNTCLOSEGUARANTEE',
#  'Age',
#  'MINORS',
#  'COUNTGUARANTEE',
#  'DURATIONGREATESTDELAYLASTYEAR',
#  'LATECOUNTPRC 181',
#  'LATECOUNTPRC 1 7',
#  'LATECOUNTPAY 1 7',
#  'LATECOUNTPAY 8 30',
#  'CRIMINAL VIOLATION',
#  'Credit load',
#  'LATECOUNTSUMM 91 180',
#  'LATECOUNTPAY 31 90',
#  'NUMBER CREDITS IN KBI 3',
#  'LATECOUNTPRC 31 90',
#  'LATECOUNTPAY 91 180',
#  'LATECOUNTPRC 8 30',
#  'CHILDREN',
#  'CLOSED CREDITS IN KBI YEAR',
#  'LATECOUNTSUMM 1 7',
#  'NUMBER REQUESTS IN KBI ALL',
#  'LATECOUNTPAY 181',
#  'LATECOUNTSUMM 181',
#  'LATECOUNTPRC 91 180',
#  'ADMINISTRATIVE VIOLATION',
#  'CLOSED CREDITS IN KBI',
#  'NUMBER CREDITS IN KBI',
#  'Loans total',
#  'COUNTOPENGUARANTEE',
#  'NUMBER REQUESTS IN KBI']

# %% [markdown]
# Пробуем обучать модель, поисследовав разные подходы была выбрана модель бустинга из библиотеки xgboost

# %%
import sklearn
import sklearn.metrics
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV

import category_encoders
from category_encoders.target_encoder import TargetEncoder

import xgboost as xgb
from xgboost import XGBClassifier

import matplotlib.pyplot as plt

SEED = 42

# %%
y = data['Marker']
X = data.drop(columns = 'Marker', inplace=False)
X = X[features]

# %%
from sklearn.preprocessing import LabelEncoder
# кодируем категориальные признаки

label_encoders = {}
for col in categorical:
        le = LabelEncoder()
        le.fit(X[col].astype('str'))
        X[col] = le.transform(X[col].astype('str'))
        label_encoders[col] = le
X[categorical].head()
# Out:
#     Application creation month  DURATION LAST OVERDUE  \
# ID
# 2                            2                      1
# 3                            0                      0
# 4                            0                      0
# 5                            1                     13
# 6                            0                      0
#
#     DURATIONGREATESTDELAYLASTALL  SEX  BIRTH CNTR  MARITAL STATUS  HOMEPHONE  \
# ID
# 2                            137    1           2               0          1
# 3                              0    0           2               0          1
# 4                              0    0          13               0          1
# 5                             20    1           2               0          1
# 6                              0    1           2               2          1
#
#     WORKPHONE  MOBILE 1  REG TOWNTYPE  HOME TOWNTYPE  EMPLOYMENT  EDUCATION  \
# ID
# 2           1         0             1              1           4          3
# 3           1         0             1              1           4          1
# 4           1         0             1              1           4          1
# 5           1         0             1              1           4          4
# 6           1         0             4              4           4          1
#
#     PROFESSION  REAL ESTATE  VEHICLE  PERSONNEL PHONE  ACCOUNTING PHONE  \
# ID
# 2            7            0        0                0                 0
# 3           13            1        1                0                 0
# 4            5            1        1                0                 0
# 5            0            1        1                0                 0
# 6           15            0        0                0                 0
#
#     Matching address of registration and residence
# ID
# 2                                                1
# 3                                                1
# 4                                                1
# 5                                                1
# 6                                                1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=SEED)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.25, random_state=SEED)

# %%
len(X_train) + len(X_valid) + len(X_test) == len(X)
# Out:
# True

# %%
params = {
    "n_estimators": 500,
    "eta": 0.3,
    "gamma": 0,
    "max_depth": 6,
    "lambda": 1,
    "alpha": 0,
    "booster": "gbtree",
    "verbosity": 2,

}

model = xgb.XGBClassifier(**params)
model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# Out:
# [23:54:37] INFO: /workspace/src/data/iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (1634, 54, 88236).
# [23:54:37] INFO: /workspace/src/data/iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (545, 54, 29430).
# [0]	validation_0-logloss:0.25653
# [1]	validation_0-logloss:0.24685
# [2]	validation_0-logloss:0.24528
# [3]	validation_0-logloss:0.24220
# [4]	validation_0-logloss:0.24155
# [5]	validation_0-logloss:0.24524
# [6]	validation_0-logloss:0.24722
# [7]	validation_0-logloss:0.25065
# [8]	validation_0-logloss:0.25266
# [9]	validation_0-logloss:0.25482
# [10]	validation_0-logloss:0.25511
# [11]	validation_0-logloss:0.25848
# [12]	validation_0-logloss:0.26031
# [13]	validation_0-logloss:0.26002
# [14]	validation_0-logloss:0.26261
# [15]	validation_0-logloss:0.26354
# [16]	validation_0-logloss:0.26876
# [17]	validation_0-logloss:0.27168
# [18]	validation_0-logloss:0.27132
# [19]	validation_0-logloss:0.27431
# [20]	validation_0-logloss:0.27435
# [21]	validation_0-logloss:0.27736
# [22]	validation_0-logloss:0.27740
# [23]	validation_0-logloss:0.27832
# [24]	validation_0-logloss:0.28128
# [25]	validation_0-logloss:0.28432
# [26]	validation_0-logloss:0.28659
# [27]	validation_0-logloss:0.28694
# [28]	validation_0-logloss:0.28964
# [29]	validation_0-logloss:0.29216
# [30]	validation_0-logloss:0.29296
# [31]	validation_0-logloss:0.29334
# [32]	validation_0-logloss:0.29351
# [33]	validation_0-logloss:0.29535
# [34]	validation_0-logloss:0.29839
# [35]	validation_0-logloss:0.30213
# [36]	validation_0-logloss:0.30302
# [37]	validation_0-logloss:0.30260
# [38]	validation_0-logloss:0.30626
# [39]	validation_0-logloss:0.30664
# [40]	validation_0-logloss:0.30828
# [41]	validation_0-logloss:0.31075
# [42]	validation_0-logloss:0.31099
# [43]	validation_0-logloss:0.31155
# [44]	validation_0-logloss:0.31354
# [45]	validation_0-logloss:0.31551
# [46]	validation_0-logloss:0.31693
# [47]	validation_0-logloss:0.31943
# [48]	validation_0-logloss:0.31967
# [49]	validation_0-logloss:0.32225
# [50]	validation_0-logloss:0.32507
# [51]	validation_0-logloss:0.32678
# [52]	validation_0-logloss:0.32729
# [53]	validation_0-logloss:0.33080
# [54]	validation_0-logloss:0.33246
# [55]	validation_0-logloss:0.33423
# [56]	validation_0-logloss:0.33481
# [57]	validation_0-logloss:0.33448
# [58]	validation_0-logloss:0.33644
# [59]	validation_0-logloss:0.34040
# [60]	validation_0-logloss:0.34075
# [61]	validation_0-logloss:0.34149
# [62]	validation_0-logloss:0.34273
# [63]	validation_0-logloss:0.34250
# [64]	validation_0-logloss:0.34391
# [65]	validation_0-logloss:0.34610
# [66]	validation_0-logloss:0.34679
# [67]	validation_0-logloss:0.34886
# [68]	validation_0-logloss:0.35081
# [69]	validation_0-logloss:0.35150
# [70]	validation_0-logloss:0.35259
# [71]	validation_0-logloss:0.35320
# [72]	validation_0-logloss:0.35366
# [73]	validation_0-logloss:0.35481
# [74]	validation_0-logloss:0.35537
# [75]	validation_0-logloss:0.35612
# [76]	validation_0-logloss:0.35806
# [77]	validation_0-logloss:0.35952
# [78]	validation_0-logloss:0.36027
# [79]	validation_0-logloss:0.36105
# [80]	validation_0-logloss:0.36179
# [81]	validation_0-logloss:0.36279
# [82]	validation_0-logloss:0.36417
# [83]	validation_0-logloss:0.36517
# [84]	validation_0-logloss:0.36649
# [85]	validation_0-logloss:0.36786
# [86]	validation_0-logloss:0.36813
# [87]	validation_0-logloss:0.36902
# [88]	validation_0-logloss:0.37014
# [89]	validation_0-logloss:0.37090
# [90]	validation_0-logloss:0.37214
# [91]	validation_0-logloss:0.37406
# [92]	validation_0-logloss:0.37553
# [93]	validation_0-logloss:0.37630
# [94]	validation_0-logloss:0.37736
# [95]	validation_0-logloss:0.37945
# [96]	validation_0-logloss:0.38105
# [97]	validation_0-logloss:0.38142
# [98]	validation_0-logloss:0.38297
# [99]	validation_0-logloss:0.38352
# [100]	validation_0-logloss:0.38414
# [101]	validation_0-logloss:0.38527
# [102]	validation_0-logloss:0.38483
# [103]	validation_0-logloss:0.38527
# [104]	validation_0-logloss:0.38533
# [105]	validation_0-logloss:0.38626
# [106]	validation_0-logloss:0.38669
# [107]	validation_0-logloss:0.38707
# [108]	validation_0-logloss:0.38764
# [109]	validation_0-logloss:0.38752
# [110]	validation_0-logloss:0.38783
# [111]	validation_0-logloss:0.38842
# [112]	validation_0-logloss:0.38865
# [113]	validation_0-logloss:0.38920
# [114]	validation_0-logloss:0.39037
# [115]	validation_0-logloss:0.39125
# [116]	validation_0-logloss:0.39180
# [117]	validation_0-logloss:0.39212
# [118]	validation_0-logloss:0.39247
# [119]	validation_0-logloss:0.39204
# [120]	validation_0-logloss:0.39225
# [121]	validation_0-logloss:0.39231
# [122]	validation_0-logloss:0.39247
# [123]	validation_0-logloss:0.39350
# [124]	validation_0-logloss:0.39320
# [125]	validation_0-logloss:0.39352
# [126]	validation_0-logloss:0.39388
# [127]	validation_0-logloss:0.39473
# [128]	validation_0-logloss:0.39486
# [129]	validation_0-logloss:0.39573
# [130]	validation_0-logloss:0.39657
# [131]	validation_0-logloss:0.39782
# [132]	validation_0-logloss:0.39814
# [133]	validation_0-logloss:0.39873
# [134]	validation_0-logloss:0.39952
# [135]	validation_0-logloss:0.40004
# [136]	validation_0-logloss:0.39998
# [137]	validation_0-logloss:0.39984
# [138]	validation_0-logloss:0.40058
# [139]	validation_0-logloss:0.40127
# [140]	validation_0-logloss:0.40206
# [141]	validation_0-logloss:0.40240
# [142]	validation_0-logloss:0.40278
# [143]	validation_0-logloss:0.40295
# [144]	validation_0-logloss:0.40346
# [145]	validation_0-logloss:0.40425
# [146]	validation_0-logloss:0.40451
# [147]	validation_0-logloss:0.40576
# [148]	validation_0-logloss:0.40695
# [149]	validation_0-logloss:0.40749
# [150]	validation_0-logloss:0.40765
# [151]	validation_0-logloss:0.40747
# [152]	validation_0-logloss:0.40827
# [153]	validation_0-logloss:0.40883
# [154]	validation_0-logloss:0.40959
# [155]	validation_0-logloss:0.40992
# [156]	validation_0-logloss:0.41083
# [157]	validation_0-logloss:0.41035
# [158]	validation_0-logloss:0.41050
# [159]	validation_0-logloss:0.41116
# [160]	validation_0-logloss:0.41140
# [161]	validation_0-logloss:0.41225
# [162]	validation_0-logloss:0.41288
# [163]	validation_0-logloss:0.41289
# [164]	validation_0-logloss:0.41342
# [165]	validation_0-logloss:0.41320
# [166]	validation_0-logloss:0.41367
# [167]	validation_0-logloss:0.41389
# [168]	validation_0-logloss:0.41408
# [169]	validation_0-logloss:0.41499
# [170]	validation_0-logloss:0.41533
# [171]	validation_0-logloss:0.41562
# [172]	validation_0-logloss:0.41544
# [173]	validation_0-logloss:0.41612
# [174]	validation_0-logloss:0.41718
# [175]	validation_0-logloss:0.41745
# [176]	validation_0-logloss:0.41778
# [177]	validation_0-logloss:0.41848
# [178]	validation_0-logloss:0.41868
# [179]	validation_0-logloss:0.41907
# [180]	validation_0-logloss:0.41944
# [181]	validation_0-logloss:0.41942
# [182]	validation_0-logloss:0.42035
# [183]	validation_0-logloss:0.42047
# [184]	validation_0-logloss:0.42104
# [185]	validation_0-logloss:0.42124
# [186]	validation_0-logloss:0.42109
# [187]	validation_0-logloss:0.42152
# [188]	validation_0-logloss:0.42168
# [189]	validation_0-logloss:0.42155
# [190]	validation_0-logloss:0.42156
# [191]	validation_0-logloss:0.42202
# [192]	validation_0-logloss:0.42221
# [193]	validation_0-logloss:0.42308
# [194]	validation_0-logloss:0.42369
# [195]	validation_0-logloss:0.42420
# [196]	validation_0-logloss:0.42487
# [197]	validation_0-logloss:0.42533
# [198]	validation_0-logloss:0.42618
# [199]	validation_0-logloss:0.42647
# [200]	validation_0-logloss:0.42709
# [201]	validation_0-logloss:0.42766
# [202]	validation_0-logloss:0.42740
# [203]	validation_0-logloss:0.42818
# [204]	validation_0-logloss:0.42845
# [205]	validation_0-logloss:0.42840
# [206]	validation_0-logloss:0.42911
# [207]	validation_0-logloss:0.42934
# [208]	validation_0-logloss:0.42957
# [209]	validation_0-logloss:0.42929
# [210]	validation_0-logloss:0.42989
# [211]	validation_0-logloss:0.43044
# [212]	validation_0-logloss:0.43058
# [213]	validation_0-logloss:0.43068
# [214]	validation_0-logloss:0.43167
# [215]	validation_0-logloss:0.43200
# [216]	validation_0-logloss:0.43205
# [217]	validation_0-logloss:0.43204
# [218]	validation_0-logloss:0.43324
# [219]	validation_0-logloss:0.43403
# [220]	validation_0-logloss:0.43401
# [221]	validation_0-logloss:0.43416
# [222]	validation_0-logloss:0.43443
# [223]	validation_0-logloss:0.43429
# [224]	validation_0-logloss:0.43546
# [225]	validation_0-logloss:0.43567
# [226]	validation_0-logloss:0.43619
# [227]	validation_0-logloss:0.43657
# [228]	validation_0-logloss:0.43684
# [229]	validation_0-logloss:0.43671
# [230]	validation_0-logloss:0.43674
# [231]	validation_0-logloss:0.43695
# [232]	validation_0-logloss:0.43668
# [233]	validation_0-logloss:0.43667
# [234]	validation_0-logloss:0.43708
# [235]	validation_0-logloss:0.43719
# [236]	validation_0-logloss:0.43790
# [237]	validation_0-logloss:0.43802
# [238]	validation_0-logloss:0.43818
# [239]	validation_0-logloss:0.43769
# [240]	validation_0-logloss:0.43749
# [241]	validation_0-logloss:0.43776
# [242]	validation_0-logloss:0.43836
# [243]	validation_0-logloss:0.43877
# [244]	validation_0-logloss:0.43922
# [245]	validation_0-logloss:0.43918
# [246]	validation_0-logloss:0.43950
# [247]	validation_0-logloss:0.43984
# [248]	validation_0-logloss:0.43989
# [249]	validation_0-logloss:0.44034
# [250]	validation_0-logloss:0.44009
# [251]	validation_0-logloss:0.44032
# [252]	validation_0-logloss:0.44089
# [253]	validation_0-logloss:0.44126
# [254]	validation_0-logloss:0.44115
# [255]	validation_0-logloss:0.44136
# [256]	validation_0-logloss:0.44229
# [257]	validation_0-logloss:0.44247
# [258]	validation_0-logloss:0.44302
# [259]	validation_0-logloss:0.44318
# [260]	validation_0-logloss:0.44357
# [261]	validation_0-logloss:0.44380
# [262]	validation_0-logloss:0.44372
# [263]	validation_0-logloss:0.44413
# [264]	validation_0-logloss:0.44433
# [265]	validation_0-logloss:0.44453
# [266]	validation_0-logloss:0.44448
# [267]	validation_0-logloss:0.44449
# [268]	validation_0-logloss:0.44447
# [269]	validation_0-logloss:0.44456
# [270]	validation_0-logloss:0.44499
# [271]	validation_0-logloss:0.44534
# [272]	validation_0-logloss:0.44594
# [273]	validation_0-logloss:0.44620
# [274]	validation_0-logloss:0.44673
# [275]	validation_0-logloss:0.44669
# [276]	validation_0-logloss:0.44674
# [277]	validation_0-logloss:0.44667
# [278]	validation_0-logloss:0.44652
# [279]	validation_0-logloss:0.44656
# [280]	validation_0-logloss:0.44688
# [281]	validation_0-logloss:0.44699
# [282]	validation_0-logloss:0.44728
# [283]	validation_0-logloss:0.44727
# [284]	validation_0-logloss:0.44770
# [285]	validation_0-logloss:0.44733
# [286]	validation_0-logloss:0.44711
# [287]	validation_0-logloss:0.44778
# [288]	validation_0-logloss:0.44822
# [289]	validation_0-logloss:0.44881
# [290]	validation_0-logloss:0.44885
# [291]	validation_0-logloss:0.44899
# [292]	validation_0-logloss:0.44907
# [293]	validation_0-logloss:0.44933
# [294]	validation_0-logloss:0.44921
# [295]	validation_0-logloss:0.44925
# [296]	validation_0-logloss:0.45011
# [297]	validation_0-logloss:0.44982
# [298]	validation_0-logloss:0.45015
# [299]	validation_0-logloss:0.45081
# [300]	validation_0-logloss:0.45122
# [301]	validation_0-logloss:0.45152
# [302]	validation_0-logloss:0.45159
# [303]	validation_0-logloss:0.45178
# [304]	validation_0-logloss:0.45160
# [305]	validation_0-logloss:0.45175
# [306]	validation_0-logloss:0.45215
# [307]	validation_0-logloss:0.45220
# [308]	validation_0-logloss:0.45210
# [309]	validation_0-logloss:0.45264
# [310]	validation_0-logloss:0.45278
# [311]	validation_0-logloss:0.45305
# [312]	validation_0-logloss:0.45318
# [313]	validation_0-logloss:0.45319
# [314]	validation_0-logloss:0.45330
# [315]	validation_0-logloss:0.45390
# [316]	validation_0-logloss:0.45386
# [317]	validation_0-logloss:0.45447
# [318]	validation_0-logloss:0.45439
# [319]	validation_0-logloss:0.45459
# [320]	validation_0-logloss:0.45477
# [321]	validation_0-logloss:0.45467
# [322]	validation_0-logloss:0.45482
# [323]	validation_0-logloss:0.45469
# [324]	validation_0-logloss:0.45536
# [325]	validation_0-logloss:0.45511
# [326]	validation_0-logloss:0.45601
# [327]	validation_0-logloss:0.45616
# [328]	validation_0-logloss:0.45635
# [329]	validation_0-logloss:0.45670
# [330]	validation_0-logloss:0.45689
# [331]	validation_0-logloss:0.45698
# [332]	validation_0-logloss:0.45680
# [333]	validation_0-logloss:0.45703
# [334]	validation_0-logloss:0.45712
# [335]	validation_0-logloss:0.45749
# [336]	validation_0-logloss:0.45720
# [337]	validation_0-logloss:0.45664
# [338]	validation_0-logloss:0.45693
# [339]	validation_0-logloss:0.45715
# [340]	validation_0-logloss:0.45715
# [341]	validation_0-logloss:0.45761
# [342]	validation_0-logloss:0.45828
# [343]	validation_0-logloss:0.45806
# [344]	validation_0-logloss:0.45839
# [345]	validation_0-logloss:0.45859
# [346]	validation_0-logloss:0.45881
# [347]	validation_0-logloss:0.45888
# [348]	validation_0-logloss:0.45940
# [349]	validation_0-logloss:0.45956
# [350]	validation_0-logloss:0.45937
# [351]	validation_0-logloss:0.45951
# [352]	validation_0-logloss:0.45987
# [353]	validation_0-logloss:0.45997
# [354]	validation_0-logloss:0.45956
# [355]	validation_0-logloss:0.46009
# [356]	validation_0-logloss:0.46046
# [357]	validation_0-logloss:0.46066
# [358]	validation_0-logloss:0.46089
# [359]	validation_0-logloss:0.46096
# [360]	validation_0-logloss:0.46116
# [361]	validation_0-logloss:0.46147
# [362]	validation_0-logloss:0.46147
# [363]	validation_0-logloss:0.46142
# [364]	validation_0-logloss:0.46185
# [365]	validation_0-logloss:0.46212
# [366]	validation_0-logloss:0.46217
# [367]	validation_0-logloss:0.46228
# [368]	validation_0-logloss:0.46246
# [369]	validation_0-logloss:0.46298
# [370]	validation_0-logloss:0.46330
# [371]	validation_0-logloss:0.46350
# [372]	validation_0-logloss:0.46320
# [373]	validation_0-logloss:0.46327
# [374]	validation_0-logloss:0.46296
# [375]	validation_0-logloss:0.46331
# [376]	validation_0-logloss:0.46298
# [377]	validation_0-logloss:0.46289
# [378]	validation_0-logloss:0.46288
# [379]	validation_0-logloss:0.46289
# [380]	validation_0-logloss:0.46289
# [381]	validation_0-logloss:0.46321
# [382]	validation_0-logloss:0.46295
# [383]	validation_0-logloss:0.46300
# [384]	validation_0-logloss:0.46322
# [385]	validation_0-logloss:0.46323
# [386]	validation_0-logloss:0.46356
# [387]	validation_0-logloss:0.46358
# [388]	validation_0-logloss:0.46374
# [389]	validation_0-logloss:0.46360
# [390]	validation_0-logloss:0.46395
# [391]	validation_0-logloss:0.46389
# [392]	validation_0-logloss:0.46434
# [393]	validation_0-logloss:0.46444
# [394]	validation_0-logloss:0.46446
# [395]	validation_0-logloss:0.46457
# [396]	validation_0-logloss:0.46449
# [397]	validation_0-logloss:0.46446
# [398]	validation_0-logloss:0.46491
# [399]	validation_0-logloss:0.46490
# [400]	validation_0-logloss:0.46489
# [401]	validation_0-logloss:0.46534
# [402]	validation_0-logloss:0.46562
# [403]	validation_0-logloss:0.46564
# [404]	validation_0-logloss:0.46532
# [405]	validation_0-logloss:0.46491
# [406]	validation_0-logloss:0.46521
# [407]	validation_0-logloss:0.46506
# [408]	validation_0-logloss:0.46533
# [409]	validation_0-logloss:0.46542
# [410]	validation_0-logloss:0.46534
# [411]	validation_0-logloss:0.46537
# [412]	validation_0-logloss:0.46527
# [413]	validation_0-logloss:0.46546
# [414]	validation_0-logloss:0.46552
# [415]	validation_0-logloss:0.46583
# [416]	validation_0-logloss:0.46595
# [417]	validation_0-logloss:0.46578
# [418]	validation_0-logloss:0.46606
# [419]	validation_0-logloss:0.46600
# [420]	validation_0-logloss:0.46616
# [421]	validation_0-logloss:0.46611
# [422]	validation_0-logloss:0.46601
# [423]	validation_0-logloss:0.46609
# [424]	validation_0-logloss:0.46658
# [425]	validation_0-logloss:0.46694
# [426]	validation_0-logloss:0.46686
# [427]	validation_0-logloss:0.46691
# [428]	validation_0-logloss:0.46704
# [429]	validation_0-logloss:0.46701
# [430]	validation_0-logloss:0.46695
# [431]	validation_0-logloss:0.46708
# [432]	validation_0-logloss:0.46710
# [433]	validation_0-logloss:0.46744
# [434]	validation_0-logloss:0.46706
# [435]	validation_0-logloss:0.46691
# [436]	validation_0-logloss:0.46704
# [437]	validation_0-logloss:0.46759
# [438]	validation_0-logloss:0.46772
# [439]	validation_0-logloss:0.46776
# [440]	validation_0-logloss:0.46782
# [441]	validation_0-logloss:0.46816
# [442]	validation_0-logloss:0.46812
# [443]	validation_0-logloss:0.46822
# [444]	validation_0-logloss:0.46812
# [445]	validation_0-logloss:0.46849
# [446]	validation_0-logloss:0.46875
# [447]	validation_0-logloss:0.46887
# [448]	validation_0-logloss:0.46888
# [449]	validation_0-logloss:0.46917
# [450]	validation_0-logloss:0.46914
# [451]	validation_0-logloss:0.46946
# [452]	validation_0-logloss:0.46972
# [453]	validation_0-logloss:0.46985
# [454]	validation_0-logloss:0.46991
# [455]	validation_0-logloss:0.46996
# [456]	validation_0-logloss:0.46973
# [457]	validation_0-logloss:0.46987
# [458]	validation_0-logloss:0.46993
# [459]	validation_0-logloss:0.47018
# [460]	validation_0-logloss:0.47014
# [461]	validation_0-logloss:0.47015
# [462]	validation_0-logloss:0.46991
# [463]	validation_0-logloss:0.47048
# [464]	validation_0-logloss:0.47086
# [465]	validation_0-logloss:0.47084
# [466]	validation_0-logloss:0.47090
# [467]	validation_0-logloss:0.47117
# [468]	validation_0-logloss:0.47107
# [469]	validation_0-logloss:0.47118
# [470]	validation_0-logloss:0.47144
# [471]	validation_0-logloss:0.47172
# [472]	validation_0-logloss:0.47178
# [473]	validation_0-logloss:0.47192
# [474]	validation_0-logloss:0.47200
# [475]	validation_0-logloss:0.47195
# [476]	validation_0-logloss:0.47215
# [477]	validation_0-logloss:0.47243
# [478]	validation_0-logloss:0.47243
# [479]	validation_0-logloss:0.47245
# [480]	validation_0-logloss:0.47277
# [481]	validation_0-logloss:0.47275
# [482]	validation_0-logloss:0.47284
# [483]	validation_0-logloss:0.47247
# [484]	validation_0-logloss:0.47235
# [485]	validation_0-logloss:0.47214
# [486]	validation_0-logloss:0.47235
# [487]	validation_0-logloss:0.47259
# [488]	validation_0-logloss:0.47274
# [489]	validation_0-logloss:0.47318
# [490]	validation_0-logloss:0.47320
# [491]	validation_0-logloss:0.47339
# [492]	validation_0-logloss:0.47366
# [493]	validation_0-logloss:0.47388
# [494]	validation_0-logloss:0.47437
# [495]	validation_0-logloss:0.47457
# [496]	validation_0-logloss:0.47460
# [497]	validation_0-logloss:0.47493
# [498]	validation_0-logloss:0.47463
# [499]	validation_0-logloss:0.47429
# XGBClassifier(alpha=0, base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.3, eval_metric=None,
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=1, learning_rate=None,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, ...)

# %%
model_es = xgb.XGBClassifier(**params, early_stopping_rounds = 20)
model_es.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
# Out:
# [23:54:41] INFO: /workspace/src/data/iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (1634, 54, 88236).
# [23:54:41] INFO: /workspace/src/data/iterative_dmatrix.cc:53: Finished constructing the `IterativeDMatrix`: (545, 54, 29430).
# [0]	validation_0-logloss:0.25653
# [1]	validation_0-logloss:0.24685
# [2]	validation_0-logloss:0.24528
# [3]	validation_0-logloss:0.24220
# [4]	validation_0-logloss:0.24155
# [5]	validation_0-logloss:0.24524
# [6]	validation_0-logloss:0.24722
# [7]	validation_0-logloss:0.25065
# [8]	validation_0-logloss:0.25266
# [9]	validation_0-logloss:0.25482
# [10]	validation_0-logloss:0.25511
# [11]	validation_0-logloss:0.25848
# [12]	validation_0-logloss:0.26031
# [13]	validation_0-logloss:0.26002
# [14]	validation_0-logloss:0.26261
# [15]	validation_0-logloss:0.26354
# [16]	validation_0-logloss:0.26876
# [17]	validation_0-logloss:0.27168
# [18]	validation_0-logloss:0.27132
# [19]	validation_0-logloss:0.27431
# [20]	validation_0-logloss:0.27435
# [21]	validation_0-logloss:0.27736
# [22]	validation_0-logloss:0.27740
# [23]	validation_0-logloss:0.27832
# [24]	validation_0-logloss:0.28128
# XGBClassifier(alpha=0, base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=20,
#               enable_categorical=False, eta=0.3, eval_metric=None,
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=1, learning_rate=None,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, ...)

# %%
results_full = model.evals_result()
results_es = model_es.evals_result()

plt.figure(figsize=(10,5))
plt.plot(results_full["validation_0"]["logloss"], label="full model loss")
plt.plot(results_es["validation_0"]["logloss"], label="early stopping loss")
plt.axvline(7, color="gray", label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend();

# %% [markdown]
# На графике показано, что RMSE снижается только в течение первых 7 итераций. Затем она начинает расти. Ранняя остановка сокращает время обучения, поскольку модель останавливается, если её характеристики не улучшаются. Кроме того, сохраняется модель с наименьшей ошибкой, а не последняя.

# %%
pred = model.predict_proba(X_test)[:,1]
roc_auc_score(y_test, pred)
# Out:
# np.float64(0.7978409443926685)

# %%
pred = model_es.predict_proba(X_test)[:,1]
roc_auc_score(y_test, pred)
# Out:
# np.float64(0.7942684063373718)

# %%
param_grid = {
    "n_estimators": [5, 10, 15, 20, 50],
    "eta": [1e-1, 1e-2, 3e-1],
    "gamma": [0.1, 1],
    "max_depth": [4, 6, 8],
    "lambda": [0.1, 1],
    "alpha": [0,0.1,1],
    "verbosity": [0]
}

xgb_model = xgb.XGBClassifier()

grid_search = GridSearchCV(
    estimator=xgb_model, param_grid=param_grid, cv=5, n_jobs=-1)


grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=Non...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'alpha': [0, 0.1, 1], 'eta': [0.1, 0.01, 0.3],
#                          'gamma': [0.1, 1], 'lambda': [0.1, 1],
#                          'max_depth': [4, 6, 8],
#                          'n_estimators': [5, 10, 15, 20, 50],
#                          'verbosity': [0]})

# %%
parameters = grid_search.best_params_
parameters["early_stopping_rounds"] = 10
parameters
# Out:
# {'alpha': 0.1,
#  'eta': 0.1,
#  'gamma': 1,
#  'lambda': 1,
#  'max_depth': 4,
#  'n_estimators': 50,
#  'verbosity': 0,
#  'early_stopping_rounds': 10}

# %%
model_best = xgb.XGBClassifier(**parameters)
model_best.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
results = model_best.evals_result()
# Out:
# [0]	validation_0-logloss:0.26014
# [1]	validation_0-logloss:0.25618
# [2]	validation_0-logloss:0.25213
# [3]	validation_0-logloss:0.25036
# [4]	validation_0-logloss:0.24787
# [5]	validation_0-logloss:0.24637
# [6]	validation_0-logloss:0.24438
# [7]	validation_0-logloss:0.24167
# [8]	validation_0-logloss:0.24094
# [9]	validation_0-logloss:0.23882
# [10]	validation_0-logloss:0.23745
# [11]	validation_0-logloss:0.23780
# [12]	validation_0-logloss:0.23766
# [13]	validation_0-logloss:0.23727
# [14]	validation_0-logloss:0.23579
# [15]	validation_0-logloss:0.23567
# [16]	validation_0-logloss:0.23584
# [17]	validation_0-logloss:0.23582
# [18]	validation_0-logloss:0.23485
# [19]	validation_0-logloss:0.23457
# [20]	validation_0-logloss:0.23466
# [21]	validation_0-logloss:0.23391
# [22]	validation_0-logloss:0.23303
# [23]	validation_0-logloss:0.23343
# [24]	validation_0-logloss:0.23349
# [25]	validation_0-logloss:0.23402
# [26]	validation_0-logloss:0.23371
# [27]	validation_0-logloss:0.23345
# [28]	validation_0-logloss:0.23365
# [29]	validation_0-logloss:0.23407
# [30]	validation_0-logloss:0.23520
# [31]	validation_0-logloss:0.23595
# [32]	validation_0-logloss:0.23682

# %%
pred = model_best.predict_proba(X_test)[:,1]
roc_auc_score(y_test, pred)
# Out:
# np.float64(0.8193150046598322)

# %%
import joblib

joblib.dump(model_best, '/XGBoost.joblib', compress=True)
joblib.dump(label_encoders, '/label_encoders.joblib', compress=True)
# Out:
# ['/label_encoders.joblib']

# %%
modelReload=joblib.load('/XGBoost.joblib')
pred_new = modelReload.predict_proba(X_test)[:,1]

# %%
roc_auc_score(y_test, pred_new)
# Out:
# np.float64(0.8193150046598322)

# %%
# из интересного здесь можно посмотреть feature_importance
import shap

shap_test = shap.TreeExplainer(model_best).shap_values(X_test)
shap.summary_plot(shap_test, X_test, max_display=30)

# %%
explanation= shap.Explanation(values=shap_test,
                             data=X_test,
                             feature_names=X_test.columns)
shap.plots.bar(explanation, max_display=10)

# %% [markdown]
# Мы имеем задачу с бинарной классификацией.
# Получился roc_auc_score 0.82, что является достаточно хорошим показателем, для такой метрики идеальная классификатор имеет скор 1.0.
#
# Оценка AUC-ROC (площадь под кривой рабочей характеристики приемника) представляет собой единую метрику, которая суммирует общую производительность бинарной классификации, что указывает на его способность различать положительные и отрицательные классы.

# %% [markdown]
# Так же можно потестировать модель логистической регрессии, но они как правило показывают хуже результат, еще из бустингов можно попробовать lightgbm или randomforest, сделать более тщательный тьюнинг гиперпараметров можно с помощью фреймворка optuna.
